# %% [markdown]
# <a href="https://colab.research.google.com/github/vibhavjoshi123/Parkinson-Detection-using-Deep-Learning/blob/master/Wave_VGG_parkinson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/My Drive/wave.zip" -d "/content"

# %% [markdown]
# ### Import all dependencies

# %%
from __future__ import print_function, division
from builtins import range, input
import cv2 
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from skimage import io


from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from glob import glob
import pandas as pd
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Define Few Parameters

# %%
#define size to which images are to be resized
IMAGE_SIZE = [224, 224] # feel free to change depending on dataset

# training config:
epochs = 500
batch_size = 32

#define paths
healthy_path = 'wave/training/healthy'
parkinson_path = 'wave/training/parkinson'

# Use glob to grab images from path .jpg or jpeg
parkinson_files= glob(parkinson_path + '/*')
healthy_files = glob(healthy_path + '/*')

# %% [markdown]
# ### Fetch Images and Class Labels from Files (This might take a while)

# %%
# Preparing Labels
parkinson_labels = []
healthy_labels = []

parkinson_images=[]
healthy_images=[]



for i in range(len(parkinson_files)):
  image = cv2.imread(parkinson_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  parkinson_images.append(image)
  parkinson_labels.append('parkinson')
  
for i in range(len(healthy_files)):
  image = cv2.imread(healthy_files[i])
  try:
  


    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  except:
    continue
  image = cv2.resize(image,(224,224))
  healthy_images.append(image)
  healthy_labels.append('healthy')

# %% [markdown]
# ### Visualize First 40 Images from Data set

# %%
# look at a random image for fun
def plot_images(images, title):
    nrows, ncols = 2, 4
    figsize = [10, 6]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()
plot_images(parkinson_images, 'Parkinson')
plot_images(healthy_images, 'Healthy')

# %% [markdown]
# ### **Normalization**
# #### Model takes images in the form of array of pixels. Hence convert into array and *normalize*

# %%
# Convert to array and Normalize to interval of [0,1]
parkinson_images = np.array(parkinson_images) / 255
healthy_images = np.array(healthy_images) / 255

# %% [markdown]
# ### **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# split into training and testing
parkinson_x_train, parkinson_x_test, parkinson_y_train, parkinson_y_test = train_test_split(
    parkinson_images, parkinson_labels, test_size=0.2)
healthy_x_train, healthy_x_test, healthy_y_train, healthy_y_test = train_test_split(
    healthy_images, healthy_labels, test_size=0.2)


X_train = np.concatenate((healthy_x_train, parkinson_x_train), axis=0)
X_test = np.concatenate((healthy_x_test, parkinson_x_test), axis=0)
y_train = np.concatenate((healthy_y_train, parkinson_y_train), axis=0)
y_test = np.concatenate((healthy_y_test, parkinson_y_test), axis=0)

# make labels into categories - either 0 or 1
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %% [markdown]
# ### Visualize a few images from Training and Test sets

# %%
plot_images(parkinson_x_train, 'X_train')
plot_images(parkinson_x_test, 'X_test')

# %% [markdown]
# ### **Building and Visualizing model**

# %%
vggModel = VGG19(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

outputs = vggModel.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=vggModel.input, outputs=outputs)

for layer in vggModel.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 50178
# =================================================================
# Total params: 20,074,562
# Trainable params: 50,178
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# ### **Image Augmentation**
# To train on images at different positions, angles, flips, etc

# %%
train_aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

# %% [markdown]
# ### **Training the model**

# %%
history = model.fit(train_aug.flow(X_train, y_train, batch_size=4),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / 4,
                    steps_per_epoch=len(X_train) / 4,
                    epochs=100)
# Out:
# Epoch 1/100
# 20/19 [==============================] - 2s 78ms/step - loss: 2.0018 - accuracy: 0.4810 - val_loss: 2.0915 - val_accuracy: 0.5714
# Epoch 2/100
# 20/19 [==============================] - 1s 50ms/step - loss: 1.2955 - accuracy: 0.6203 - val_loss: 0.9012 - val_accuracy: 0.8095
# Epoch 3/100
# 20/19 [==============================] - 1s 50ms/step - loss: 0.4589 - accuracy: 0.7848 - val_loss: 0.6723 - val_accuracy: 0.8095
# Epoch 4/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.7534 - accuracy: 0.7342 - val_loss: 0.6978 - val_accuracy: 0.8095
# Epoch 5/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.5007 - accuracy: 0.8354 - val_loss: 0.6923 - val_accuracy: 0.8095
# Epoch 6/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.3282 - accuracy: 0.8608 - val_loss: 0.8862 - val_accuracy: 0.8095
# Epoch 7/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.5452 - accuracy: 0.8228 - val_loss: 0.8830 - val_accuracy: 0.8095
# Epoch 8/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.7391 - accuracy: 0.7468 - val_loss: 0.6583 - val_accuracy: 0.8571
# Epoch 9/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.5018 - accuracy: 0.8354 - val_loss: 0.5029 - val_accuracy: 0.7143
# Epoch 10/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.5222 - accuracy: 0.8228 - val_loss: 0.4325 - val_accuracy: 0.8095
# Epoch 11/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.3120 - accuracy: 0.8608 - val_loss: 0.4977 - val_accuracy: 0.8571
# Epoch 12/100
# 20/19 [==============================] - 1s 50ms/step - loss: 0.5212 - accuracy: 0.7848 - val_loss: 1.2777 - val_accuracy: 0.7619
# Epoch 13/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.4764 - accuracy: 0.8354 - val_loss: 0.5707 - val_accuracy: 0.8571
# Epoch 21/100
# 20/19 [==============================] - 1s 50ms/step - loss: 0.2544 - accuracy: 0.8987 - val_loss: 0.5296 - val_accuracy: 0.7619
# Epoch 22/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.4091 - accuracy: 0.8734 - val_loss: 0.5955 - val_accuracy: 0.7143
# Epoch 23/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.5176 - accuracy: 0.8734 - val_loss: 0.6367 - val_accuracy: 0.8571
# Epoch 24/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.5673 - accuracy: 0.8354 - val_loss: 0.9114 - val_accuracy: 0.8095
# Epoch 25/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.5987 - accuracy: 0.8101 - val_loss: 0.7592 - val_accuracy: 0.7143
# Epoch 26/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.3653 - accuracy: 0.9241 - val_loss: 0.6396 - val_accuracy: 0.7143
# Epoch 27/100
# 20/19 [==============================] - 1s 46ms/step - loss: 0.3118 - accuracy: 0.8734 - val_loss: 0.6561 - val_accuracy: 0.7143
# Epoch 28/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.3437 - accuracy: 0.8608 - val_loss: 0.8631 - val_accuracy: 0.6190
# Epoch 29/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.7203 - accuracy: 0.7848 - val_loss: 0.6584 - val_accuracy: 0.7143
# Epoch 30/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.3972 - accuracy: 0.8861 - val_loss: 1.1766 - val_accuracy: 0.5714
# Epoch 31/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.4992 - accuracy: 0.8228 - val_loss: 0.7360 - val_accuracy: 0.8095
# Epoch 32/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.3925 - accuracy: 0.8734 - val_loss: 0.9493 - val_accuracy: 0.6190
# Epoch 33/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.6543 - accuracy: 0.7975 - val_loss: 0.7113 - val_accuracy: 0.7143
# Epoch 34/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.2492 - accuracy: 0.8987 - val_loss: 0.7699 - val_accuracy: 0.7143
# Epoch 35/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.2056 - accuracy: 0.9241 - val_loss: 0.6814 - val_accuracy: 0.7619
# Epoch 36/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.4437 - accuracy: 0.8734 - val_loss: 0.7186 - val_accuracy: 0.8571
# Epoch 37/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.3740 - accuracy: 0.8228 - val_loss: 0.5975 - val_accuracy: 0.8095
# Epoch 38/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.2724 - accuracy: 0.9241 - val_loss: 1.0085 - val_accuracy: 0.6190
# Epoch 39/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.3313 - accuracy: 0.8987 - val_loss: 0.9282 - val_accuracy: 0.6667
# Epoch 40/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.2670 - accuracy: 0.9114 - val_loss: 1.0082 - val_accuracy: 0.6190
# Epoch 41/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.5245 - accuracy: 0.8228 - val_loss: 0.7113 - val_accuracy: 0.8095
# Epoch 42/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.5671 - accuracy: 0.8354 - val_loss: 1.1607 - val_accuracy: 0.7619
# Epoch 43/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.5115 - accuracy: 0.8734 - val_loss: 0.6709 - val_accuracy: 0.7619
# Epoch 44/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.1344 - accuracy: 0.9367 - val_loss: 0.7133 - val_accuracy: 0.7619
# Epoch 45/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.2402 - accuracy: 0.9241 - val_loss: 0.7027 - val_accuracy: 0.8571
# Epoch 46/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.6300 - accuracy: 0.7975 - val_loss: 0.8027 - val_accuracy: 0.6667
# Epoch 47/100
# 20/19 [==============================] - 1s 46ms/step - loss: 0.4071 - accuracy: 0.8861 - val_loss: 0.6679 - val_accuracy: 0.8571
# Epoch 48/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.2643 - accuracy: 0.8987 - val_loss: 0.8361 - val_accuracy: 0.6667
# Epoch 49/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.4764 - accuracy: 0.8228 - val_loss: 0.8968 - val_accuracy: 0.6667
# Epoch 50/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.1777 - accuracy: 0.9367 - val_loss: 1.0982 - val_accuracy: 0.8095
# Epoch 51/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.6350 - accuracy: 0.8228 - val_loss: 1.0580 - val_accuracy: 0.8571
# Epoch 52/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.3988 - accuracy: 0.8987 - val_loss: 0.6572 - val_accuracy: 0.9048
# Epoch 53/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.3226 - accuracy: 0.8861 - val_loss: 0.8791 - val_accuracy: 0.9048
# Epoch 54/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.2892 - accuracy: 0.9241 - val_loss: 0.7096 - val_accuracy: 0.9048
# Epoch 55/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.5037 - accuracy: 0.8481 - val_loss: 0.8090 - val_accuracy: 0.9048
# Epoch 56/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.3534 - accuracy: 0.8987 - val_loss: 1.0847 - val_accuracy: 0.8571
# Epoch 57/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.4656 - accuracy: 0.8734 - val_loss: 2.2099 - val_accuracy: 0.6667
# Epoch 58/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.5850 - accuracy: 0.8481 - val_loss: 0.7737 - val_accuracy: 0.9048
# Epoch 59/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.4256 - accuracy: 0.9114 - val_loss: 1.1193 - val_accuracy: 0.7143
# Epoch 60/100
# 20/19 [==============================] - 1s 50ms/step - loss: 0.4686 - accuracy: 0.8481 - val_loss: 1.2730 - val_accuracy: 0.5714
# Epoch 61/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.6693 - accuracy: 0.8734 - val_loss: 1.2055 - val_accuracy: 0.8571
# Epoch 62/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.4165 - accuracy: 0.8987 - val_loss: 1.1151 - val_accuracy: 0.8571
# Epoch 63/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.5117 - accuracy: 0.8861 - val_loss: 0.6616 - val_accuracy: 0.8571
# Epoch 64/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.4334 - accuracy: 0.8987 - val_loss: 0.8162 - val_accuracy: 0.9048
# Epoch 65/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.2676 - accuracy: 0.9241 - val_loss: 1.1006 - val_accuracy: 0.8571
# Epoch 66/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.5464 - accuracy: 0.8608 - val_loss: 1.0582 - val_accuracy: 0.8571
# Epoch 67/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.4099 - accuracy: 0.8861 - val_loss: 0.8092 - val_accuracy: 0.9048
# Epoch 68/100
# 20/19 [==============================] - 1s 50ms/step - loss: 0.2892 - accuracy: 0.9367 - val_loss: 1.3383 - val_accuracy: 0.8571
# Epoch 69/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.3845 - accuracy: 0.8987 - val_loss: 0.7421 - val_accuracy: 0.7619
# Epoch 70/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.5639 - accuracy: 0.8481 - val_loss: 0.8249 - val_accuracy: 0.7619
# Epoch 71/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.1099 - accuracy: 0.9620 - val_loss: 0.7663 - val_accuracy: 0.9048
# Epoch 72/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.5145 - accuracy: 0.8734 - val_loss: 1.0922 - val_accuracy: 0.8571
# Epoch 73/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.3337 - accuracy: 0.8987 - val_loss: 0.8297 - val_accuracy: 0.9048
# Epoch 74/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.6676 - accuracy: 0.8481 - val_loss: 1.6381 - val_accuracy: 0.8095
# Epoch 75/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.8272 - accuracy: 0.8354 - val_loss: 0.9593 - val_accuracy: 0.7143
# Epoch 76/100
# 20/19 [==============================] - 1s 51ms/step - loss: 0.3514 - accuracy: 0.9114 - val_loss: 0.8683 - val_accuracy: 0.8095
# Epoch 77/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.3458 - accuracy: 0.8861 - val_loss: 0.9845 - val_accuracy: 0.8571
# Epoch 78/100
# 20/19 [==============================] - 1s 46ms/step - loss: 0.2427 - accuracy: 0.9494 - val_loss: 1.0809 - val_accuracy: 0.6190
# Epoch 79/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.1426 - accuracy: 0.9494 - val_loss: 0.8389 - val_accuracy: 0.7619
# Epoch 80/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.2387 - accuracy: 0.9494 - val_loss: 0.9414 - val_accuracy: 0.9048
# Epoch 81/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.1408 - accuracy: 0.9367 - val_loss: 1.3117 - val_accuracy: 0.6190
# Epoch 82/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.6503 - accuracy: 0.8608 - val_loss: 1.0074 - val_accuracy: 0.7143
# Epoch 83/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.4642 - accuracy: 0.8861 - val_loss: 1.1030 - val_accuracy: 0.8571
# Epoch 84/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.4580 - accuracy: 0.8608 - val_loss: 1.4276 - val_accuracy: 0.8095
# Epoch 85/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.2353 - accuracy: 0.9114 - val_loss: 1.2704 - val_accuracy: 0.8571
# Epoch 86/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.4441 - accuracy: 0.8987 - val_loss: 0.9255 - val_accuracy: 0.7619
# Epoch 87/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.5555 - accuracy: 0.8734 - val_loss: 1.0833 - val_accuracy: 0.7143
# Epoch 88/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.4142 - accuracy: 0.8861 - val_loss: 0.9623 - val_accuracy: 0.8571
# Epoch 89/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.2925 - accuracy: 0.9114 - val_loss: 1.3421 - val_accuracy: 0.8571
# Epoch 90/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.5242 - accuracy: 0.8987 - val_loss: 1.4799 - val_accuracy: 0.8095
# Epoch 91/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.3505 - accuracy: 0.8608 - val_loss: 1.0829 - val_accuracy: 0.8571
# Epoch 92/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.6459 - accuracy: 0.8734 - val_loss: 1.0495 - val_accuracy: 0.8571
# Epoch 93/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.2571 - accuracy: 0.9241 - val_loss: 1.0319 - val_accuracy: 0.7619
# Epoch 94/100
# 20/19 [==============================] - 1s 49ms/step - loss: 0.4056 - accuracy: 0.8354 - val_loss: 1.5320 - val_accuracy: 0.5714
# Epoch 95/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.4302 - accuracy: 0.8734 - val_loss: 1.5659 - val_accuracy: 0.5714
# Epoch 96/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.4900 - accuracy: 0.9114 - val_loss: 1.2365 - val_accuracy: 0.6667
# Epoch 97/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.0457 - accuracy: 0.9873 - val_loss: 0.9581 - val_accuracy: 0.8571
# Epoch 98/100
# 20/19 [==============================] - 1s 47ms/step - loss: 0.3069 - accuracy: 0.9114 - val_loss: 1.4355 - val_accuracy: 0.8095
# Epoch 99/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.3446 - accuracy: 0.9114 - val_loss: 0.9436 - val_accuracy: 0.7619
# Epoch 100/100
# 20/19 [==============================] - 1s 48ms/step - loss: 0.1977 - accuracy: 0.9367 - val_loss: 1.0390 - val_accuracy: 0.7619

# %%
model.save('parkinson.h5')

# %%
model.save_weights('parkinsonweights.hdf5')

# %%
model = load_model('parkinson.h5')

# %% [markdown]
# ### **Making Predicions**

# %%
y_pred = model.predict(X_test, batch_size=batch_size)

# %% [markdown]
# ### Visulaizing First 10 predictions

# %%
prediction=y_pred[0:10]
for index, probability in enumerate(prediction):
  if probability[1] > 0.5:
        plt.title('%.2f' % (probability[1]*100) + '% PARKINSON')
  else:
        plt.title('%.2f' % ((1-probability[1])*100) + '% HEALTHY')
  plt.imshow(X_test[index])
  plt.show()

# %%
# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %% [markdown]
# ### Plot ROC Curve

# %%
fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve for our model')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %% [markdown]
# ### Plot Confusion Matrix

# %%
def plot_confusion_matrix(normalize):
  classes = ['PARKINSON','HEALTHY']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='plasma',annot=True)
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  plt.title('Confusion Matrix')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

print('Confusion Matrix without Normalization')
plot_confusion_matrix(normalize=None)

print('Confusion Matrix with Normalized Values')
plot_confusion_matrix(normalize='true')
# Out:
# Confusion Matrix without Normalization
# Confusion Matrix with Normalized Values

# %% [markdown]
# ### **Classification Report**

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.70      0.74        10
#            1       0.75      0.82      0.78        11
#
#     accuracy                           0.76        21
#    macro avg       0.76      0.76      0.76        21
# weighted avg       0.76      0.76      0.76        21

# %% [markdown]
# ### **Accuracy and Loss Plots**

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('vgg_chest_accuracy.png')
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('parkinson_loss.png')
plt.show()
